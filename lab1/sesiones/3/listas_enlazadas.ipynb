# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/tigarto/2018-1/blob/master/listas_enlazadas.ipynb)

# %%
# !pip3 install tutormagic

# %%
# %load_ext tutormagic

# %% [markdown]
# # Listas enlazadas

# %% [markdown]
# El código mostrado a continuación se tomo de: [Algoritmos y estructuras de datos: Una perspectiva en C
# ](http://novella.mhhe.com/sites/844814077x/information_center_view0/index.html)

# %% [markdown]
# ## Construcción de una lista

# %% [markdown]
# **Declaración de un nodo**

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include  <stdlib.h>
#
# typedef double elemento;
#
# typedef struct nodo {
#     elemento dato;
#     struct nodo *enlace;
# } nodo;
#
# int main() {
#   printf("En el ejemplo solo se declara una estructura tipo nodo\n");
#   return 0;
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%20%3Cstdlib.h%3E%0A%0Atypedef%20double%20elemento%3B%0A%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20elemento%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Aenlace%3B%0A%7D%20nodo%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20printf%28%22En%20el%20ejemplo%20solo%20se%20declara%20una%20estructura%20tipo%20nodo%5Cn%22%29%3B%0A%20%20return%200%3B%20%20%0A%7D&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=c&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>

# %% [markdown]
# **Puntero cabecera y cola**

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include  <stdlib.h>
#
# typedef double elemento;
#
# typedef struct nodo {
#     elemento dato;
#     struct nodo *enlace;
# } nodo;
#
# nodo *ptr_cabecera;   // Asociado al primer nodo
# nodo *ptr_cola;       // Asociado al ultimo nodo
#
# int main() {
#   ptr_cabecera = NULL;
#   printf("Solo se declaran punteros asociados a la cabeza y a la cola\n");
#   return 0;
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%20%3Cstdlib.h%3E%0A%0Atypedef%20double%20elemento%3B%0A%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20elemento%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Aenlace%3B%0A%7D%20nodo%3B%0A%0Anodo%20%2Aptr_cabecera%3B%20%20%20//%20Asociado%20al%20primer%20nodo%0Anodo%20%2Aptr_cola%3B%20%20%20%20%20%20%20//%20Asociado%20al%20ultimo%20nodo%0A%0Aint%20main%28%29%20%7B%0A%20%20ptr_cabecera%20%3D%20NULL%3B%0A%20%20printf%28%22Solo%20se%20declaran%20punteros%20asociados%20a%20la%20cabeza%20y%20a%20la%20cola%5Cn%22%29%3B%0A%20%20return%200%3B%20%20%0A%7D&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=c&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>

# %% [markdown]
# **Construcción de una lista**

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include  <stdlib.h>
#
#
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# int main() {
#   nodo *primero = NULL;  // Cabecera
#   primero = malloc(sizeof(nodo));
#   primero->dato = 11;
#   primero->siguiente = NULL; // Se creo una lista de solo un elemento: (H) -> (11)
#   free(primero);
#   primero = NULL;
#   return 0;
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%20%3Cstdlib.h%3E%0A%0A%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%20%20//%20Cabecera%0A%20%20primero%20%3D%20malloc%28sizeof%28nodo%29%29%3B%20%20%0A%20%20primero-%3Edato%20%3D%2011%3B%0A%20%20primero-%3Esiguiente%20%3D%20NULL%3B%20//%20Se%20creo%20una%20lista%20de%20solo%20un%20elemento%3A%20%28H%29%20-%3E%20%2811%29%0A%20%20free%28primero%29%3B%20%20%0A%20%20primero%20%3D%20NULL%3B%20%20%0A%20%20return%200%3B%20%20%0A%7D&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=c&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>

# %% [markdown]
# **Creación de un nodo**
#
# >**Declaracion**:
# > ```C
# > nodo crearNodo(int d,nodo *enlace);
# > ```
# >
# >
# >**Definición**:
# >
# > ```C
# > nodo crearNodo(int d,nodo *enlace){
# >   nodo *p = malloc(sizeof(nodo));
# >   p->dato = d;
# >   p->siguiente = enlace;
# >   return p;
# > }
# > ```

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d,nodo *enlace);
#
# int main() {
#   nodo *primero = NULL;
#   primero = crearNodo(11,NULL);    // (H) -> (11)
#   primero = crearNodo(6,primero);  // (H) -> (6) -> (11)
#   primero = crearNodo(4,primero);  // (H) -> (4) -> (6) -> (11)
#   free(primero);
#   primero = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d,nodo *enlace) {
#   nodo *p = malloc(sizeof(nodo));
#   p->dato = d;
#   p->siguiente = enlace;
#   return p;
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%2Cnodo%20%2Aenlace%29%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20primero%20%3D%20crearNodo%2811%2CNULL%29%3B%20%20%20%20//%20%28H%29%20-%3E%20%2811%29%0A%20%20primero%20%3D%20crearNodo%286%2Cprimero%29%3B%20%20//%20%28H%29%20-%3E%20%286%29%20-%3E%20%2811%29%20%0A%20%20primero%20%3D%20crearNodo%284%2Cprimero%29%3B%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%286%29%20-%3E%20%2811%29%0A%20%20free%28primero%29%3B%0A%20%20primero%20%3D%20NULL%3B%20%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%2Cnodo%20%2Aenlace%29%20%7B%0A%20%20nodo%20%2Ap%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20p-%3Edato%20%3D%20d%3B%0A%20%20p-%3Esiguiente%20%3D%20enlace%3B%0A%20%20return%20p%3B%0A%7D&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=c&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>

# %% [markdown]
# ## Inserción de un elemento en una lista

# %% [markdown]
# **Ejemplo**: Suponga que se tiene una lista con 3 elementos (10, 25, 40). El objetivo es insertar un nuevo elemento con valor 4 en la cabeza.

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d,nodo *enlace);
#
# int main() {
#   nodo *primero = NULL;
#   primero = crearNodo(40,NULL);        // (H) -> (40)
#   primero = crearNodo(25,primero);     // (H) -> (25) -> (40)
#   primero = crearNodo(10,primero);     // (H) -> (10) -> (25) -> (40)
#   // nuevo elemento
#   nodo *nuevo = malloc(sizeof(nodo));
#   nuevo->dato = 4;
#   nuevo->siguiente = primero;
#   primero = nuevo;                     // (H) -> (4) -> (10) -> (25) -> (40)
#   free(primero);
#   primero = NULL;
#   nuevo = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d,nodo *enlace) {
#   nodo *p = malloc(sizeof(nodo));
#   p->dato = d;
#   p->siguiente = enlace;
#   return p;
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%2Cnodo%20%2Aenlace%29%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20primero%20%3D%20crearNodo%2840%2CNULL%29%3B%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%2840%29%0A%20%20primero%20%3D%20crearNodo%2825%2Cprimero%29%3B%20%20%20%20%20//%20%28H%29%20-%3E%20%2825%29%20-%3E%20%2840%29%20%0A%20%20primero%20%3D%20crearNodo%2810%2Cprimero%29%3B%20%20%20%20%20//%20%28H%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20//%20nuevo%20elemento%0A%20%20nodo%20%2Anuevo%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20nuevo-%3Edato%20%3D%204%3B%0A%20%20nuevo-%3Esiguiente%20%3D%20primero%3B%20%20%0A%20%20primero%20%3D%20nuevo%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20free%28primero%29%3B%0A%20%20primero%20%3D%20NULL%3B%20%0A%20%20nuevo%20%3D%20NULL%3B%20%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%2Cnodo%20%2Aenlace%29%20%7B%0A%20%20nodo%20%2Ap%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20p-%3Edato%20%3D%20d%3B%0A%20%20p-%3Esiguiente%20%3D%20enlace%3B%0A%20%20return%20p%3B%0A%7D&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=c&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>

# %% [markdown]
# **Función para insertar un nodo al principio de la lista**
#
# >**Declaracion**:
# > ```C
# > void insertarPrimero(nodo **cabeza, int d);
# > ```
# >
# >
# >**Definición**:
# >
# > ```C
# > void insertarPrimero(nodo **cabeza, int d) {
# >   nodo *nuevo;
# >   nuevo = malloc(sizeof(nodo));
# >   nuevo->dato = d;
# >   nuevo->siguiente = cabeza;
# >   *cabeza = nuevo;
# > }
# > ```

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d,nodo *enlace);
# void insertarPrimero(nodo **cabeza, int d);
# int main() {
#   nodo *primero = NULL;
#   insertarPrimero(&primero,40);        // (H) -> (40)
#   insertarPrimero(&primero,25);        // (H) -> (25) -> (40)
#   insertarPrimero(&primero,10);        // (H) -> (10) -> (25) -> (40)
#   insertarPrimero(&primero,4);         // (H) -> (4) -> (10) -> (25) -> (40)
#   primero = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d,nodo *enlace) {
#   nodo *p = malloc(sizeof(nodo));
#   p->dato = d;
#   p->siguiente = enlace;
#   return p;
# }
#
# void insertarPrimero(nodo **cabeza, int d) {
#   nodo *nuevo;
#   nuevo = malloc(sizeof(nodo));
#   nuevo->dato = d;
#   nuevo->siguiente = *cabeza;
#   *cabeza = nuevo;
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%2Cnodo%20%2Aenlace%29%3B%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%20%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20insertarPrimero%28%26primero%2C40%29%3B%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%2840%29%0A%20%20insertarPrimero%28%26primero%2C25%29%3B%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%2825%29%20-%3E%20%2840%29%20%0A%20%20insertarPrimero%28%26primero%2C10%29%3B%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20insertarPrimero%28%26primero%2C4%29%3B%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20primero%20%3D%20NULL%3B%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%2Cnodo%20%2Aenlace%29%20%7B%0A%20%20nodo%20%2Ap%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20p-%3Edato%20%3D%20d%3B%0A%20%20p-%3Esiguiente%20%3D%20enlace%3B%0A%20%20return%20p%3B%0A%7D%0A%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%3B%0A%20%20nuevo%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20nuevo-%3Edato%20%3D%20d%3B%0A%20%20nuevo-%3Esiguiente%20%3D%20%2Acabeza%3B%0A%20%20%2Acabeza%20%3D%20nuevo%3B%0A%7D&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=c&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>

# %% [markdown]
# **Función para insertar un nodo al final de la lista**
#
# >**Declaracion**:
# > ```C
# > void insertarFinal(nodo **cabeza, int d);
# > ```
# >
# >
# >**Definición**:
# >
# > ```C
# > void insertarFinal(nodo **cabeza, int d) {
# >   nodo *ultimo;
# >   ultimo = *cabeza;
# >   if(ultimo == NULL) {
# >     *cabeza = crearNodo(d);
# >   }
# >   else {
# >     for(;ultimo->siguiente;) {
# >       ultimo = ultimo->siguiente;
# >     }
# >     ultimo->siguiente = crearNodo(d);
# >   }
# > }
# > ```
#
# La función empleada como apoyo se muestra a continuación:
#
# >**Declaracion**:
# > ```C
# > nodo *crearNodo(int d);
# > ```
# >
# >
# >**Definición**:
# >
# > ```C
# > nodo *crearNodo(int d) {
# >   nodo *a = malloc(sizeof(nodo));
# >   a->dato = d;
# >   a->siguiente = NULL;
# >   return a;
# > }
# > ```

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d);
# void insertarPrimero(nodo **cabeza, int d);
# void insertarFinal(nodo **cabeza, int d);
#
# int main() {
#   nodo *primero = NULL;
#   insertarFinal(&primero,4);          // (H) -> (4)
#   insertarFinal(&primero,10);         // (H) -> (4) -> (10)
#   insertarFinal(&primero,25);         // (H) -> (4) -> (10) -> (25)
#   insertarFinal(&primero,40);         // (H) -> (4) -> (10) -> (25) -> (40)
#   primero = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d) {
#   nodo *a = malloc(sizeof(nodo));
#   a->dato = d;
#   a->siguiente = NULL;
#   return a;
# }
#
# void insertarPrimero(nodo **cabeza, int d) {
#   nodo *nuevo;
#   nuevo = malloc(sizeof(nodo));
#   nuevo->dato = d;
#   nuevo->siguiente = *cabeza;
#   *cabeza = nuevo;
# }
#
# void insertarFinal(nodo **cabeza, int d) {
#   nodo *ultimo;
#   ultimo = *cabeza;
#   if(ultimo == NULL) {
#     *cabeza = crearNodo(d);
#   }
#   else {
#     for(;ultimo->siguiente;) {
#       ultimo = ultimo->siguiente;
#     }
#     ultimo->siguiente = crearNodo(d);
#   }
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%3B%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%20%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20insertarFinal%28%26primero%2C4%29%3B%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%0A%20%20insertarFinal%28%26primero%2C10%29%3B%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20%0A%20%20insertarFinal%28%26primero%2C25%29%3B%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%0A%20%20insertarFinal%28%26primero%2C40%29%3B%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20primero%20%3D%20NULL%3B%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%20%7B%0A%20%20nodo%20%2Aa%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20a-%3Edato%20%3D%20d%3B%0A%20%20a-%3Esiguiente%20%3D%20NULL%3B%0A%20%20return%20a%3B%0A%7D%0A%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%3B%0A%20%20nuevo%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20nuevo-%3Edato%20%3D%20d%3B%0A%20%20nuevo-%3Esiguiente%20%3D%20%2Acabeza%3B%0A%20%20%2Acabeza%20%3D%20nuevo%3B%0A%7D%0A%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Aultimo%3B%0A%20%20ultimo%20%3D%20%2Acabeza%3B%0A%20%20if%28ultimo%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20for%28%3Bultimo-%3Esiguiente%3B%29%20%7B%0A%20%20%20%20%20%20ultimo%20%3D%20ultimo-%3Esiguiente%3B%0A%20%20%20%20%7D%0A%20%20%20%20ultimo-%3Esiguiente%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%7D&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=c&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>

# %% [markdown]
# **Insertar nodo entre dos nodos**
#
# >**Declaracion**:
# > ```C
# > void insertar(nodo **cabeza, int d_cmp, int d);
# > ```
# >
# >
# >**Definición**:
# >
# > ```C
# > void insertar(nodo **cabeza, int d_cmp, int d) {
# >   nodo *nuevo, *despues;
# >   nuevo = crearNodo(d);
# >   if(*cabeza == NULL) {
# >     *cabeza = nuevo;
# >   }
# >   else {
# >     int ban = 0;
# >     despues = *cabeza;
# >     /* Etapa de busqueda */
# >     while((despues != NULL) && !ban) {
# >       if(despues->dato != d_cmp) {
# >         despues = despues->siguiente;
# >       }
# >       else {
# >         ban = 1;
# >       }
# >     }
# >     /* Etapa de insercion */
# >     if(ban) {
# >       nuevo->siguiente = despues->siguiente;
# >       despues->siguiente = nuevo;
# >     }
# >   }
# > }
# > ```

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d);
# void insertarPrimero(nodo **cabeza, int d);
# void insertarFinal(nodo **cabeza, int d);
# void insertar(nodo **cabeza, int d_cmp, int d);
#
# int main() {
#   nodo *primero = NULL;
#   insertar(&primero, 0, 4);               // (H) -> (4)
#   insertar(&primero, 4, 40);              // (H) -> (4) -> (40)
#   insertar(&primero, 4, 10);              // (H) -> (4) -> (10) -> (40)
#   insertar(&primero, 10, 25);             // (H) -> (4) -> (10) -> (25) -> (40)
#   primero = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d) {
#   nodo *a = malloc(sizeof(nodo));
#   a->dato = d;
#   a->siguiente = NULL;
#   return a;
# }
#
# void insertarPrimero(nodo **cabeza, int d) {
#   nodo *nuevo;
#   nuevo = malloc(sizeof(nodo));
#   nuevo->dato = d;
#   nuevo->siguiente = *cabeza;
#   *cabeza = nuevo;
# }
#
# void insertarFinal(nodo **cabeza, int d) {
#   nodo *ultimo;
#   ultimo = *cabeza;
#   if(ultimo == NULL) {
#     *cabeza = crearNodo(d);
#   }
#   else {
#     for(;ultimo->siguiente;) {
#       ultimo = ultimo->siguiente;
#     }
#     ultimo->siguiente = crearNodo(d);
#   }
# }
#
# void insertar(nodo **cabeza, int d_cmp, int d) {
#   nodo *nuevo, *despues;
#   nuevo = crearNodo(d);
#   if(*cabeza == NULL) {
#     *cabeza = nuevo;
#   }
#   else {
#     int ban = 0;
#     despues = *cabeza;
#     /* Etapa de busqueda */
#     while((despues != NULL) && !ban) {
#       if(despues->dato != d_cmp) {
#         despues = despues->siguiente;
#       }
#       else {
#         ban = 1;
#       }
#     }
#     /* Etapa de insercion */
#     if(ban) {
#       nuevo->siguiente = despues->siguiente;
#       despues->siguiente = nuevo;
#     }
#   }
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%3B%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%20%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20insertar%28%26primero%2C%200%2C%204%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%0A%20%20insertar%28%26primero%2C%204%2C%2040%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2840%29%20%0A%20%20insertar%28%26primero%2C%204%2C%2010%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2840%29%0A%20%20insertar%28%26primero%2C%2010%2C%2025%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20primero%20%3D%20NULL%3B%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%20%7B%0A%20%20nodo%20%2Aa%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20a-%3Edato%20%3D%20d%3B%0A%20%20a-%3Esiguiente%20%3D%20NULL%3B%0A%20%20return%20a%3B%0A%7D%0A%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%3B%0A%20%20nuevo%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20nuevo-%3Edato%20%3D%20d%3B%0A%20%20nuevo-%3Esiguiente%20%3D%20%2Acabeza%3B%0A%20%20%2Acabeza%20%3D%20nuevo%3B%0A%7D%0A%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Aultimo%3B%0A%20%20ultimo%20%3D%20%2Acabeza%3B%0A%20%20if%28ultimo%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20for%28%3Bultimo-%3Esiguiente%3B%29%20%7B%0A%20%20%20%20%20%20ultimo%20%3D%20ultimo-%3Esiguiente%3B%0A%20%20%20%20%7D%0A%20%20%20%20ultimo-%3Esiguiente%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%7D%0A%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%2C%20%2Adespues%3B%20%0A%20%20nuevo%20%3D%20crearNodo%28d%29%3B%0A%20%20if%28%2Acabeza%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20nuevo%3B%20%20%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20int%20ban%20%3D%200%3B%0A%20%20%20%20despues%20%3D%20%2Acabeza%3B%0A%20%20%20%20/%2A%20Etapa%20de%20busqueda%20%2A/%20%20%0A%20%20%20%20while%28%28despues%20%21%3D%20NULL%29%20%26%26%20%21ban%29%20%7B%0A%20%20%20%20%20%20if%28despues-%3Edato%20%21%3D%20d_cmp%29%20%7B%0A%20%20%20%20%20%20%20%20despues%20%3D%20despues-%3Esiguiente%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20else%20%7B%0A%20%20%20%20%20%20%20%20ban%20%3D%201%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%20%20%20%20/%2A%20Etapa%20de%20insercion%20%2A/%20%20%0A%20%20%20%20if%28ban%29%20%7B%0A%20%20%20%20%20%20nuevo-%3Esiguiente%20%3D%20despues-%3Esiguiente%3B%0A%20%20%20%20%20%20despues-%3Esiguiente%20%3D%20nuevo%3B%20%20%0A%20%20%20%20%7D%20%20%0A%20%20%7D%20%0A%7D&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=c&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25>Python Tutor</a></strong></div>

# %% [markdown]
# ## Busqueda en listas enlazadas

# %% [markdown]
# **Busqueda por valor**
#
# >**Declaracion**:
# > ```C
# > nodo *localizar(nodo *cabeza, int d);
# > ```
# >
# >
# >**Definición**:
# >
# > ```C
# > nodo *localizar(nodo *cabeza, int d) {
# >   nodo *indice;
# >   for(indice = cabeza; indice != NULL; indice = indice->siguiente) {
# >     if(d == indice->dato) {
# >       return indice;
# >     }
# >   }
# >   return NULL;
# > }
# > ```

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d);
# void insertarPrimero(nodo **cabeza, int d);
# void insertarFinal(nodo **cabeza, int d);
# void insertar(nodo **cabeza, int d_cmp, int d);
# nodo *localizar(nodo *cabeza, int d);
#
# int main() {
#   nodo *primero = NULL;
#   insertar(&primero, 0, 4);               // (H) -> (4)
#   insertar(&primero, 4, 40);              // (H) -> (4) -> (40)
#   insertar(&primero, 4, 10);              // (H) -> (4) -> (10) -> (40)
#   insertar(&primero, 10, 25);             // (H) -> (4) -> (10) -> (25) -> (40)
#   /* Test localizando nodos (10) y (25) */
#   nodo *n10 = localizar(primero,10);
#   nodo *n25 = localizar(primero,25);
#   primero = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d) {
#   nodo *a = malloc(sizeof(nodo));
#   a->dato = d;
#   a->siguiente = NULL;
#   return a;
# }
#
# void insertarPrimero(nodo **cabeza, int d) {
#   nodo *nuevo;
#   nuevo = malloc(sizeof(nodo));
#   nuevo->dato = d;
#   nuevo->siguiente = *cabeza;
#   *cabeza = nuevo;
# }
#
# void insertarFinal(nodo **cabeza, int d) {
#   nodo *ultimo;
#   ultimo = *cabeza;
#   if(ultimo == NULL) {
#     *cabeza = crearNodo(d);
#   }
#   else {
#     for(;ultimo->siguiente;) {
#       ultimo = ultimo->siguiente;
#     }
#     ultimo->siguiente = crearNodo(d);
#   }
# }
#
# void insertar(nodo **cabeza, int d_cmp, int d) {
#   nodo *nuevo, *despues;
#   nuevo = crearNodo(d);
#   if(*cabeza == NULL) {
#     *cabeza = nuevo;
#   }
#   else {
#     int ban = 0;
#     despues = *cabeza;
#     /* Etapa de busqueda */
#     while((despues != NULL) && !ban) {
#       if(despues->dato != d_cmp) {
#         despues = despues->siguiente;
#       }
#       else {
#         ban = 1;
#       }
#     }
#     /* Etapa de insercion */
#     if(ban) {
#       nuevo->siguiente = despues->siguiente;
#       despues->siguiente = nuevo;
#     }
#   }
# }
#
# nodo *localizar(nodo *cabeza, int d) {
#   nodo *indice;
#   for(indice = cabeza; indice != NULL; indice = indice->siguiente) {
#     if(d == indice->dato) {
#       return indice;
#     }
#   }
#   return NULL;
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%3B%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%20%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%3B%0Anodo%20%2Alocalizar%28nodo%20%2Acabeza%2C%20int%20d%29%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20insertar%28%26primero%2C%200%2C%204%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%0A%20%20insertar%28%26primero%2C%204%2C%2040%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2840%29%20%0A%20%20insertar%28%26primero%2C%204%2C%2010%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2840%29%0A%20%20insertar%28%26primero%2C%2010%2C%2025%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20/%2A%20Test%20localizando%20nodos%20%2810%29%20y%20%2825%29%20%2A/%0A%20%20nodo%20%2An10%20%3D%20localizar%28primero%2C10%29%3B%20%20%0A%20%20nodo%20%2An25%20%3D%20localizar%28primero%2C25%29%3B%20%20%0A%20%20primero%20%3D%20NULL%3B%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%20%7B%0A%20%20nodo%20%2Aa%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20a-%3Edato%20%3D%20d%3B%0A%20%20a-%3Esiguiente%20%3D%20NULL%3B%0A%20%20return%20a%3B%0A%7D%0A%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%3B%0A%20%20nuevo%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20nuevo-%3Edato%20%3D%20d%3B%0A%20%20nuevo-%3Esiguiente%20%3D%20%2Acabeza%3B%0A%20%20%2Acabeza%20%3D%20nuevo%3B%0A%7D%0A%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Aultimo%3B%0A%20%20ultimo%20%3D%20%2Acabeza%3B%0A%20%20if%28ultimo%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20for%28%3Bultimo-%3Esiguiente%3B%29%20%7B%0A%20%20%20%20%20%20ultimo%20%3D%20ultimo-%3Esiguiente%3B%0A%20%20%20%20%7D%0A%20%20%20%20ultimo-%3Esiguiente%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%7D%0A%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%2C%20%2Adespues%3B%20%0A%20%20nuevo%20%3D%20crearNodo%28d%29%3B%0A%20%20if%28%2Acabeza%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20nuevo%3B%20%20%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20int%20ban%20%3D%200%3B%0A%20%20%20%20despues%20%3D%20%2Acabeza%3B%0A%20%20%20%20/%2A%20Etapa%20de%20busqueda%20%2A/%20%20%0A%20%20%20%20while%28%28despues%20%21%3D%20NULL%29%20%26%26%20%21ban%29%20%7B%0A%20%20%20%20%20%20if%28despues-%3Edato%20%21%3D%20d_cmp%29%20%7B%0A%20%20%20%20%20%20%20%20despues%20%3D%20despues-%3Esiguiente%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20else%20%7B%0A%20%20%20%20%20%20%20%20ban%20%3D%201%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%20%20%20%20/%2A%20Etapa%20de%20insercion%20%2A/%20%20%0A%20%20%20%20if%28ban%29%20%7B%0A%20%20%20%20%20%20nuevo-%3Esiguiente%20%3D%20despues-%3Esiguiente%3B%0A%20%20%20%20%20%20despues-%3Esiguiente%20%3D%20nuevo%3B%20%20%0A%20%20%20%20%7D%20%20%0A%20%20%7D%20%0A%7D%0A%0Anodo%20%2Alocalizar%28nodo%20%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Aindice%3B%0A%20%20for%28indice%20%3D%20cabeza%3B%20indice%20%21%3D%20NULL%3B%20indice%20%3D%20indice-%3Esiguiente%29%20%7B%0A%20%20%20%20if%28d%20%3D%3D%20indice-%3Edato%29%20%7B%0A ...

# %% [markdown]
# **Buscar posicion**
#
# >**Declaracion**:
# > ```C
# > nodo *buscarPosicion(nodo *cabeza, int pos);
# > ```
# >
# >
# >**Definición**:
# >
# > ```C
# > nodo *buscarPosicion(nodo *cabeza, int pos) {
# >   nodo *indice;
# >   int i;
# >   if(pos < 1) {
# >     return NULL;
# >   }
# >   indice = cabeza;
# >   for(i = 1; (i < pos) && (indice != NULL); i++) {
# >     indice = indice->siguiente;
# >   }
# >   return indice;
# > }
# > ```

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d);
# void insertarPrimero(nodo **cabeza, int d);
# void insertarFinal(nodo **cabeza, int d);
# void insertar(nodo **cabeza, int d_cmp, int d);
# nodo *localizar(nodo *cabeza, int d);
# nodo *buscarPosicion(nodo *cabeza, int pos);
#
# int main() {
#   nodo *primero = NULL;
#   insertar(&primero, 0, 4);               // (H) -> (4)
#   insertar(&primero, 4, 40);              // (H) -> (4) -> (40)
#   insertar(&primero, 4, 10);              // (H) -> (4) -> (10) -> (40)
#   insertar(&primero, 10, 25);             // (H) -> (4) -> (10) -> (25) -> (40)
#   /* Test localizando nodos (4) y (10) por posicion */
#   nodo *n10 = buscarPosicion(primero,1);
#   nodo *n25 = buscarPosicion(primero,2);
#   primero = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d) {
#   nodo *a = malloc(sizeof(nodo));
#   a->dato = d;
#   a->siguiente = NULL;
#   return a;
# }
#
# void insertarPrimero(nodo **cabeza, int d) {
#   nodo *nuevo;
#   nuevo = malloc(sizeof(nodo));
#   nuevo->dato = d;
#   nuevo->siguiente = *cabeza;
#   *cabeza = nuevo;
# }
#
# void insertarFinal(nodo **cabeza, int d) {
#   nodo *ultimo;
#   ultimo = *cabeza;
#   if(ultimo == NULL) {
#     *cabeza = crearNodo(d);
#   }
#   else {
#     for(;ultimo->siguiente;) {
#       ultimo = ultimo->siguiente;
#     }
#     ultimo->siguiente = crearNodo(d);
#   }
# }
#
# void insertar(nodo **cabeza, int d_cmp, int d) {
#   nodo *nuevo, *despues;
#   nuevo = crearNodo(d);
#   if(*cabeza == NULL) {
#     *cabeza = nuevo;
#   }
#   else {
#     int ban = 0;
#     despues = *cabeza;
#     /* Etapa de busqueda */
#     while((despues != NULL) && !ban) {
#       if(despues->dato != d_cmp) {
#         despues = despues->siguiente;
#       }
#       else {
#         ban = 1;
#       }
#     }
#     /* Etapa de insercion */
#     if(ban) {
#       nuevo->siguiente = despues->siguiente;
#       despues->siguiente = nuevo;
#     }
#   }
# }
#
# nodo *localizar(nodo *cabeza, int d) {
#   nodo *indice;
#   for(indice = cabeza; indice != NULL; indice = indice->siguiente) {
#     if(d == indice->dato) {
#       return indice;
#     }
#   }
#   return NULL;
# }
#
# nodo *buscarPosicion(nodo *cabeza, int pos) {
#   nodo *indice;
#   int i;
#   if(pos < 1) {
#     return NULL;
#   }
#   indice = cabeza;
#   for(i = 1; (i < pos) && (indice != NULL); i++) {
#     indice = indice->siguiente;
#   }
#   return indice;
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%3B%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%20%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%3B%0Anodo%20%2Alocalizar%28nodo%20%2Acabeza%2C%20int%20d%29%3B%0Anodo%20%2AbuscarPosicion%28nodo%20%2Acabeza%2C%20int%20pos%29%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20insertar%28%26primero%2C%200%2C%204%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%0A%20%20insertar%28%26primero%2C%204%2C%2040%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2840%29%20%0A%20%20insertar%28%26primero%2C%204%2C%2010%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2840%29%0A%20%20insertar%28%26primero%2C%2010%2C%2025%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20/%2A%20Test%20localizando%20nodos%20%284%29%20y%20%2810%29%20por%20posicion%20%2A/%0A%20%20nodo%20%2An10%20%3D%20buscarPosicion%28primero%2C1%29%3B%20%20%0A%20%20nodo%20%2An25%20%3D%20buscarPosicion%28primero%2C2%29%3B%20%20%0A%20%20primero%20%3D%20NULL%3B%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%20%7B%0A%20%20nodo%20%2Aa%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20a-%3Edato%20%3D%20d%3B%0A%20%20a-%3Esiguiente%20%3D%20NULL%3B%0A%20%20return%20a%3B%0A%7D%0A%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%3B%0A%20%20nuevo%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20nuevo-%3Edato%20%3D%20d%3B%0A%20%20nuevo-%3Esiguiente%20%3D%20%2Acabeza%3B%0A%20%20%2Acabeza%20%3D%20nuevo%3B%0A%7D%0A%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Aultimo%3B%0A%20%20ultimo%20%3D%20%2Acabeza%3B%0A%20%20if%28ultimo%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20for%28%3Bultimo-%3Esiguiente%3B%29%20%7B%0A%20%20%20%20%20%20ultimo%20%3D%20ultimo-%3Esiguiente%3B%0A%20%20%20%20%7D%0A%20%20%20%20ultimo-%3Esiguiente%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%7D%0A%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%2C%20%2Adespues%3B%20%0A%20%20nuevo%20%3D%20crearNodo%28d%29%3B%0A%20%20if%28%2Acabeza%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20nuevo%3B%20%20%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20int%20ban%20%3D%200%3B%0A%20%20%20%20despues%20%3D%20%2Acabeza%3B%0A%20%20%20%20/%2A%20Etapa%20de%20busqueda%20%2A/%20%20%0A%20%20%20%20while%28%28despues%20%21%3D%20NULL%29%20%26%26%20%21ban%29%20%7B%0A%20%20%20%20%20%20if%28despues-%3Edato%20%21%3D%20d_cmp%29%20%7B%0A%20%20%20%20%20%20%20%20despues%20%3D%20despues-%3Esiguiente%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20else%20%7B%0A%20%20%20%20%20%20%20%20ban%20%3D%201%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%20%20%20%20/%2A%20Etapa%20de%20insercion%20%2A/%20%20%0A%20%20%20%20if%28ban%29%20%7B%0A%20%20%20%20%20%20nuevo-%3Esiguiente%20%3D%20despues-%3Esiguiente%3B%0A%20%20%20%20%20%20despues-%3Esiguiente%20%3D%20nuevo%3B%20%20%0A%20%20%20%20%7D%20%20%0A%20%20%7D%20%0A%7D%0A%0Anodo%20%2Alocalizar%28nodo%20%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Aindice%3B%0A%20%20for%28indice%20%3D%20cabeza%3B%20indice%20%21%3D%20NULL%3B%20indice%20%3 ...

# %% [markdown]
# ## Eliminación de un nodo de una lista

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d);
# void insertarPrimero(nodo **cabeza, int d);
# void insertarFinal(nodo **cabeza, int d);
# void insertar(nodo **cabeza, int d_cmp, int d);
# nodo *localizar(nodo *cabeza, int d);
# nodo *buscarPosicion(nodo *cabeza, int pos);
# void eliminar(nodo **cabeza, int d);
#
# int main() {
#   nodo *primero = NULL;
#   insertar(&primero, 0, 4);               // (H) -> (4)
#   insertar(&primero, 4, 40);              // (H) -> (4) -> (40)
#   insertar(&primero, 4, 10);              // (H) -> (4) -> (10) -> (40)
#   insertar(&primero, 10, 25);             // (H) -> (4) -> (10) -> (25) -> (40)
#   /* Test eliminando los nodos (4) y (25) */
#   eliminar(&primero,4);                   // (H) -> (10) -> (25) -> (40)
#   eliminar(&primero,25);                  // (H) -> (10) -> (40)
#   primero = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d) {
#   nodo *a = malloc(sizeof(nodo));
#   a->dato = d;
#   a->siguiente = NULL;
#   return a;
# }
#
# void insertarPrimero(nodo **cabeza, int d) {
#   nodo *nuevo;
#   nuevo = malloc(sizeof(nodo));
#   nuevo->dato = d;
#   nuevo->siguiente = *cabeza;
#   *cabeza = nuevo;
# }
#
# void insertarFinal(nodo **cabeza, int d) {
#   nodo *ultimo;
#   ultimo = *cabeza;
#   if(ultimo == NULL) {
#     *cabeza = crearNodo(d);
#   }
#   else {
#     for(;ultimo->siguiente;) {
#       ultimo = ultimo->siguiente;
#     }
#     ultimo->siguiente = crearNodo(d);
#   }
# }
#
# void insertar(nodo **cabeza, int d_cmp, int d) {
#   nodo *nuevo, *despues;
#   nuevo = crearNodo(d);
#   if(*cabeza == NULL) {
#     *cabeza = nuevo;
#   }
#   else {
#     int ban = 0;
#     despues = *cabeza;
#     /* Etapa de busqueda */
#     while((despues != NULL) && !ban) {
#       if(despues->dato != d_cmp) {
#         despues = despues->siguiente;
#       }
#       else {
#         ban = 1;
#       }
#     }
#     /* Etapa de insercion */
#     if(ban) {
#       nuevo->siguiente = despues->siguiente;
#       despues->siguiente = nuevo;
#     }
#   }
# }
#
# nodo *localizar(nodo *cabeza, int d) {
#   nodo *indice;
#   for(indice = cabeza; indice != NULL; indice = indice->siguiente) {
#     if(d == indice->dato) {
#       return indice;
#     }
#   }
#   return NULL;
# }
#
# nodo *buscarPosicion(nodo *cabeza, int pos) {
#   nodo *indice;
#   int i;
#   if(pos < 1) {
#     return NULL;
#   }
#   indice = cabeza;
#   for(i = 1; (i < pos) && (indice != NULL); i++) {
#     indice = indice->siguiente;
#   }
#   return indice;
# }
#
# void eliminar(nodo **cabeza, int d) {
#   nodo *actual, *anterior;
#   int encontrado = 0;
#   actual = *cabeza;
#   anterior = NULL;
#   /* Busqueda del nodo y del anterior */
#   while((actual != NULL) && (!encontrado)) {
#     encontrado = (actual->dato == d);
#     if(!encontrado) {
#       anterior = actual;
#       actual = actual->siguiente;
#     }
#   }
#   /* Enlace de nodo anterior con siguiente */
#   if(actual != NULL) {
#     /* Distingue que el nodo sea cabecera o del resto de la lista */
#     if(actual == *cabeza) {
#       *cabeza = actual->siguiente;
#     }
#     else {
#       anterior->siguiente = actual->siguiente;
#     }
#   }
#   free(actual);
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%3B%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%20%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%3B%0Anodo%20%2Alocalizar%28nodo%20%2Acabeza%2C%20int%20d%29%3B%0Anodo%20%2AbuscarPosicion%28nodo%20%2Acabeza%2C%20int%20pos%29%3B%0Avoid%20eliminar%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%0A%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20insertar%28%26primero%2C%200%2C%204%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%0A%20%20insertar%28%26primero%2C%204%2C%2040%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2840%29%20%0A%20%20insertar%28%26primero%2C%204%2C%2010%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2840%29%0A%20%20insertar%28%26primero%2C%2010%2C%2025%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20/%2A%20Test%20eliminando%20los%20nodos%20%284%29%20y%20%2825%29%20%2A/%0A%20%20eliminar%28%26primero%2C4%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20eliminar%28%26primero%2C25%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%2810%29%20-%3E%20%2840%29%0A%20%20primero%20%3D%20NULL%3B%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%20%7B%0A%20%20nodo%20%2Aa%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20a-%3Edato%20%3D%20d%3B%0A%20%20a-%3Esiguiente%20%3D%20NULL%3B%0A%20%20return%20a%3B%0A%7D%0A%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%3B%0A%20%20nuevo%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20nuevo-%3Edato%20%3D%20d%3B%0A%20%20nuevo-%3Esiguiente%20%3D%20%2Acabeza%3B%0A%20%20%2Acabeza%20%3D%20nuevo%3B%0A%7D%0A%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Aultimo%3B%0A%20%20ultimo%20%3D%20%2Acabeza%3B%0A%20%20if%28ultimo%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20for%28%3Bultimo-%3Esiguiente%3B%29%20%7B%0A%20%20%20%20%20%20ultimo%20%3D%20ultimo-%3Esiguiente%3B%0A%20%20%20%20%7D%0A%20%20%20%20ultimo-%3Esiguiente%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%7D%0A%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%2C%20%2Adespues%3B%20%0A%20%20nuevo%20%3D%20crearNodo%28d%29%3B%0A%20%20if%28%2Acabeza%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20nuevo%3B%20%20%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20int%20ban%20%3D%200%3B%0A%20%20%20%20despues%20%3D%20%2Acabeza%3B%0A%20%20%20%20/%2A%20Etapa%20de%20busqueda%20%2A/%20%20%0A%20%20%20%20while%28%28despues%20%21%3D%20NULL%29%20%26%26%20%21ban%29%20%7B%0A%20%20%20%20%20%20if%28despues-%3Edato%20%21%3D%20d_cmp%29%20%7B%0A%20%20%20%20%20%20%20%20despues%20%3D%20despues-%3Esiguiente%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20else%20%7B%0A%20%20%20%20%20%20%20%20ban%20%3D%201%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%20%20%20%20/%2A%20Etapa%20de%20insercion%20%2A/%20%20%0A%20%20%20%20if%28ban%29%20%7B%0A%20%20%20%20%20%20nuevo-%3Esiguiente%20%3D%20despues-%3Esiguiente%3B%0A%20%20%20%20%20%20despues-%3Esiguiente%20%3D%20nuevo%3B%20%20%0A%20%20 ...

# %% [markdown]
# ## Recorrido de una lista

# %% [markdown]
# >**Declaracion**:
# > ```C
# > void recorrer(nodo *cabeza);
# > ```
# >
# >
# >**Definición**:
# >
# > ```C
# > void recorrer(nodo *cabeza) {
# >   for(;cabeza;cabeza = cabeza->siguiente) {
# >     printf("%d ", cabeza->dato);
# >   }
# >   printf("\n");
# > }
# > ```

# %%
# %%tutor -l c -k
# #include <stdio.h>
# #include <stdlib.h>
#
# // Estructura asociada al nodo
# typedef struct nodo {
#     int dato;
#     struct nodo *siguiente;
# } nodo;
#
# // Declaracion de funciones
# nodo *crearNodo(int d);
# void insertarPrimero(nodo **cabeza, int d);
# void insertarFinal(nodo **cabeza, int d);
# void insertar(nodo **cabeza, int d_cmp, int d);
# nodo *localizar(nodo *cabeza, int d);
# nodo *buscarPosicion(nodo *cabeza, int pos);
# void eliminar(nodo **cabeza, int d);
# void recorrer(nodo *cabeza);
# int main() {
#   nodo *primero = NULL;
#   insertar(&primero, 0, 4);               // (H) -> (4)
#   insertar(&primero, 4, 40);              // (H) -> (4) -> (40)
#   insertar(&primero, 4, 10);              // (H) -> (4) -> (10) -> (40)
#   insertar(&primero, 10, 25);             // (H) -> (4) -> (10) -> (25) -> (40)
#   /*Imprimiendo la lista de 4 elementos */
#   recorrer(primero);
#   eliminar(&primero,4);                   // (H) -> (10) -> (25) -> (40)
#   eliminar(&primero,25);                  // (H) -> (10) -> (40)
#   /*Imprimiendo la lista de 2 elementos */
#   recorrer(primero);
#   primero = NULL;
#   return 0;
# }
#
# // Definicion de funciones
# nodo *crearNodo(int d) {
#   nodo *a = malloc(sizeof(nodo));
#   a->dato = d;
#   a->siguiente = NULL;
#   return a;
# }
#
# void insertarPrimero(nodo **cabeza, int d) {
#   nodo *nuevo;
#   nuevo = malloc(sizeof(nodo));
#   nuevo->dato = d;
#   nuevo->siguiente = *cabeza;
#   *cabeza = nuevo;
# }
#
# void insertarFinal(nodo **cabeza, int d) {
#   nodo *ultimo;
#   ultimo = *cabeza;
#   if(ultimo == NULL) {
#     *cabeza = crearNodo(d);
#   }
#   else {
#     for(;ultimo->siguiente;) {
#       ultimo = ultimo->siguiente;
#     }
#     ultimo->siguiente = crearNodo(d);
#   }
# }
#
# void insertar(nodo **cabeza, int d_cmp, int d) {
#   nodo *nuevo, *despues;
#   nuevo = crearNodo(d);
#   if(*cabeza == NULL) {
#     *cabeza = nuevo;
#   }
#   else {
#     int ban = 0;
#     despues = *cabeza;
#     /* Etapa de busqueda */
#     while((despues != NULL) && !ban) {
#       if(despues->dato != d_cmp) {
#         despues = despues->siguiente;
#       }
#       else {
#         ban = 1;
#       }
#     }
#     /* Etapa de insercion */
#     if(ban) {
#       nuevo->siguiente = despues->siguiente;
#       despues->siguiente = nuevo;
#     }
#   }
# }
#
# nodo *localizar(nodo *cabeza, int d) {
#   nodo *indice;
#   for(indice = cabeza; indice != NULL; indice = indice->siguiente) {
#     if(d == indice->dato) {
#       return indice;
#     }
#   }
#   return NULL;
# }
#
# nodo *buscarPosicion(nodo *cabeza, int pos) {
#   nodo *indice;
#   int i;
#   if(pos < 1) {
#     return NULL;
#   }
#   indice = cabeza;
#   for(i = 1; (i < pos) && (indice != NULL); i++) {
#     indice = indice->siguiente;
#   }
#   return indice;
# }
#
# void eliminar(nodo **cabeza, int d) {
#   nodo *actual, *anterior;
#   int encontrado = 0;
#   actual = *cabeza;
#   anterior = NULL;
#   /* Busqueda del nodo y del anterior */
#   while((actual != NULL) && (!encontrado)) {
#     encontrado = (actual->dato == d);
#     if(!encontrado) {
#       anterior = actual;
#       actual = actual->siguiente;
#     }
#   }
#   /* Enlace de nodo anterior con siguiente */
#   if(actual != NULL) {
#     /* Distingue que el nodo sea cabecera o del resto de la lista */
#     if(actual == *cabeza) {
#       *cabeza = actual->siguiente;
#     }
#     else {
#       anterior->siguiente = actual->siguiente;
#     }
#   }
#   free(actual);
# }
#
# void recorrer(nodo *cabeza) {
#   for(;cabeza;cabeza = cabeza->siguiente) {
#     printf("%d ", cabeza->dato);
#   }
#   printf("\n");
# }
# Out:
# <div class="text-center"><strong><a style="box-sizing: border-box; padding: 0 5px; border: 1px solid #CFCFCF;" target="_" href=http://pythontutor.com/iframe-embed.html#code=%23include%20%3Cstdio.h%3E%0A%23include%20%3Cstdlib.h%3E%0A%0A//%20Estructura%20asociada%20al%20nodo%0Atypedef%20struct%20nodo%20%7B%0A%20%20%20%20int%20dato%3B%0A%20%20%20%20struct%20nodo%20%2Asiguiente%3B%0A%7D%20nodo%3B%0A%0A//%20Declaracion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%3B%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%20%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%3B%0Anodo%20%2Alocalizar%28nodo%20%2Acabeza%2C%20int%20d%29%3B%0Anodo%20%2AbuscarPosicion%28nodo%20%2Acabeza%2C%20int%20pos%29%3B%0Avoid%20eliminar%28nodo%20%2A%2Acabeza%2C%20int%20d%29%3B%0Avoid%20recorrer%28nodo%20%2Acabeza%29%3B%0Aint%20main%28%29%20%7B%0A%20%20nodo%20%2Aprimero%20%3D%20NULL%3B%0A%20%20insertar%28%26primero%2C%200%2C%204%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%0A%20%20insertar%28%26primero%2C%204%2C%2040%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2840%29%20%0A%20%20insertar%28%26primero%2C%204%2C%2010%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2840%29%0A%20%20insertar%28%26primero%2C%2010%2C%2025%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%284%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20/%2AImprimiendo%20la%20lista%20de%204%20elementos%20%2A/%0A%20%20recorrer%28primero%29%3B%20%20%0A%20%20eliminar%28%26primero%2C4%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%2810%29%20-%3E%20%2825%29%20-%3E%20%2840%29%0A%20%20eliminar%28%26primero%2C25%29%3B%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20//%20%28H%29%20-%3E%20%2810%29%20-%3E%20%2840%29%0A%20%20/%2AImprimiendo%20la%20lista%20de%202%20elementos%20%2A/%0A%20%20recorrer%28primero%29%3B%20%20%20%20%0A%20%20primero%20%3D%20NULL%3B%20%0A%20%20return%200%3B%0A%7D%0A%0A//%20Definicion%20de%20funciones%0Anodo%20%2AcrearNodo%28int%20d%29%20%7B%0A%20%20nodo%20%2Aa%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20a-%3Edato%20%3D%20d%3B%0A%20%20a-%3Esiguiente%20%3D%20NULL%3B%0A%20%20return%20a%3B%0A%7D%0A%0Avoid%20insertarPrimero%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%3B%0A%20%20nuevo%20%3D%20malloc%28sizeof%28nodo%29%29%3B%0A%20%20nuevo-%3Edato%20%3D%20d%3B%0A%20%20nuevo-%3Esiguiente%20%3D%20%2Acabeza%3B%0A%20%20%2Acabeza%20%3D%20nuevo%3B%0A%7D%0A%0Avoid%20insertarFinal%28nodo%20%2A%2Acabeza%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Aultimo%3B%0A%20%20ultimo%20%3D%20%2Acabeza%3B%0A%20%20if%28ultimo%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20for%28%3Bultimo-%3Esiguiente%3B%29%20%7B%0A%20%20%20%20%20%20ultimo%20%3D%20ultimo-%3Esiguiente%3B%0A%20%20%20%20%7D%0A%20%20%20%20ultimo-%3Esiguiente%20%3D%20crearNodo%28d%29%3B%0A%20%20%7D%0A%7D%0A%0Avoid%20insertar%28nodo%20%2A%2Acabeza%2C%20int%20d_cmp%2C%20int%20d%29%20%7B%0A%20%20nodo%20%2Anuevo%2C%20%2Adespues%3B%20%0A%20%20nuevo%20%3D%20crearNodo%28d%29%3B%0A%20%20if%28%2Acabeza%20%3D%3D%20NULL%29%20%7B%0A%20%20%20%20%2Acabeza%20%3D%20nuevo%3B%20%20%0A%20%20%7D%0A%20%20else%20%7B%0A%20%20%20%20int%20ban%20%3D%200%3B%0A%20%20%20%20despues%20%3D%20%2Acabeza%3B%0A%20%20%20%20/%2A%20Etapa%20de%20busqueda%20%2A/%20%20%0A%20%20%20%20while%28%28despues%20%21%3D%20NULL%29%20%26%26%20%21ban%29%20%7B%0A%20%20%20%20%20%20if%28despues-%3Edato%20%21%3D%20d_cmp%29%20%7B%0A%20%20%20%20%20%20%20%20despues%20%3D%20despues-%3Esiguiente%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20else%20%7B%0A%20%20%20%20%20%20%20%20ban%20%3D%201%3B%20%20%0A%20%20%20%20%20%20%7D%0A%20%20%20%20%7D%0A%20%20%20%20/%2A%20Etapa%20de%20insercion%20%2A/%20%20% ...
